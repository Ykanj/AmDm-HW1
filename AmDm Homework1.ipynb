# %%
#Say "Hello, World!" With Python
if __name__ == '__main__':
    print("Hello, World!")

# %%
#Recursive Digit Sum
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'superDigit' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. STRING n
#  2. INTEGER k

def superDigit(n, k):
    # this is called the digital root and is a mathmatical property such that it is equal to the remainder of division by 9
    initial = sum(int(x)for x in str(n))*k
    supered = initial % 9 
    if supered == 0:
        return 9
    else:
        return supered    
    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = first_multiple_input[0]

    k = int(first_multiple_input[1])

    result = superDigit(n, k)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Insertion Sort - Part 1
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort1' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort1(n, arr):
    current = arr[-1]
    for x in range(n-2, -1, -1):
        if arr[x] > current:
            arr[x+1] = arr[x]
            for x in arr:
                print(x, end=" ")
            print("")
        else:
            arr[x+1] = current
            for x in arr:
                print(x, end=" ")
            print("")
            break
    if current < arr[0]:
        arr[0] = current 
        for x in arr:
            print(x, end=" ")
        print("")      
if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort1(n, arr)

# %%
#Standardize Mobile Number Using Decorators

def wrapper(f):
    def fun(l):
        numbers = []
        for phone in l:
            numbers.append(f"+91 {number[-10:-5]} {number[-5:]}")
        f(numbers)
    return fun
    

@wrapper
def sort_phone(l):
    print(*sorted(l), sep='\n')

if __name__ == '__main__':
    l = [input() for _ in range(int(input()))]
    sort_phone(l)

# %%
#Python If-Else
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
if (n % 2 != 0):
    print("Weird")
elif (n <= 5 and n >=2) or n > 20:
    print("Not Weird")
else:
    print("Weird")

# %%
#Arithmetic Operators
if __name__ == '__main__':
    a = int(input())
    b = int(input())
print(a+b)
print(a-b)
print(a*b)

# %%
# loops
if __name__ == '__main__':
    n = int(input())
for x in range(n):
    print(x**2)

# %%
#write a function
def is_leap(year):
    leap = False
    if int(year) % 4 == 0:
        leap = True
        if int(year) % 100==0:
            leap = False
        if  int(year) % 100==0 and int(year) % 400==0:
            leap = True 
          

    return leap

# %%
#Python: Division
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)

# %%
#print function
if __name__ == '__main__':
    n = int(input())
for x in range(1,n+1):
    print(str(x), end='')

# %%
#List Comprehensions I imported a library to compute the permutations
if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
import itertools

X =[a for a in range(x+1)]
Y =[b for b in range(y+1)]
Z =[c for c in range(z+1)]

perms = list(itertools.product(X,Y,Z))
goodperms = []
for m in range(0,len(perms)):
    count = 0
    tot = 0
    
    while count < len(perms[m]):
        tot += perms[m][count]
        count+=1
    if tot != n:
        goodperms.append(perms[m])
for x in range(len(goodperms)):
    goodperms[x] = list(goodperms[x])
print(goodperms)

# %%
#Find the Runner-Up Score!
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    
stuff = [] 
   
for x in arr:
    stuff.append(x)
    
stuff.sort()    
stuff.reverse()

for x in range(len(stuff)):
    if stuff[x+1]<stuff[x]:
        print(stuff[x+1])
        break

# %%
#Nested Lists	
scores=[]
dicts={}
Names =[]     

if __name__ == '__main__':
    for _ in range(int(input())):
        name = input()
        score = float(input())
        scores.append(score)
        dicts[name]=score
        
scores.sort()

for x in range(len(scores)):
    if scores[x+1] > scores[x]:
        secondlowest = scores[x+1]
        break
        
for x in dicts:
    if dicts[x] == secondlowest:
        Names.append(x)
        
Names.sort()

for name in Names:
    print(name)

# %%
#Finding the percentage	
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()

tot = 0

for m in range(3):
    tot += student_marks[query_name][m] 
average = tot / 3
print("%.2f" % average)

# %%
#tuples
toople = []
if __name__ == '__main__':
    n = int(input())
    #toople.append(n)
    integer_list = map(int, input().split())
    for x in integer_list:
        toople.append(x)
print(hash(tuple(toople)))

# %%
#sWAP cASE	
#This is a python builtin string method
def swap_case(s):
    s = s.swapcase()
    return s

# %%
#String Split and Join	


def split_and_join(line):
    str = line.split(" ")
    str= "-".join(str)
    return str

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)

# %%
#What's Your Name?	#
# Complete the 'print_full_name' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. STRING first
#  2. STRING last
#

def print_full_name(first, last):
    hey ="Hello {firstname} {lastname}! You just delved into python.".format(firstname= first, lastname = last)
    print(hey)

# %%
#mutations
def mutate_string(string, position, character):
    a = list(string)
    a[position] = character
    string = "".join(a)
    return string

# %%
#Find a string	
def count_substring(string, sub_string):
    counter =0
    for x in range(len(string)-len(sub_string)+1):
        
        if sub_string == string[x:x+len(sub_string)]:
            
            counter += 1
    return counter

# %%
#String Validators	
if __name__ == '__main__':
    s = input()
alnum = False
alpha = False
digit = False
lower = False
upper = False    
for x in range(len(s)) :   
    if s[x].isalnum() == True:
        alnum = True         
    if s[x].isalpha() == True:
        alpha = True        
    if s[x].isdigit() == True:
        digit = True         
    if s[x].islower() == True:
        lower = True
    if s[x].isupper() == True:
        upper = True
print(alnum)
print(alpha)
print(digit)
print(lower)
print(upper)

# %%
#Text Wrap	



def wrap(string, max_width):
    count = 0
    newstring = ""
    for x in range(len(string)):
        newstring += string[x]
        count +=1
        if count == max_width:
            newstring +="\n"
            count = 0
    return newstring

# %%
#Designer Door Mat	
# Enter your code here. Read input from STDIN. Print output to STDOUT
l, w = map(int, input().split())

def doormat(l, w):
    for x in range(1,l, 2):
        print((".|."*x).center(w,"-"))
    print(("WELCOME").center(w,"-"))
    for x in reversed(range(1,l,2)):
        print((".|."*x).center(w,"-"))
doormat(l,w)        
#doormat(101,303)

# %%
#Text Alignment	 this solution was from the hackerrank website, i did not undertsand the given problem or how to solve it
#Replace all ______ with rjust, ljust or center. 

thickness = int(input()) #This must be an odd number
c = 'H'

#Top Cone
for i in range(thickness):
    print((c*i).______(thickness-1)+c+(c*i).______(thickness-1))

#Top Pillars
for i in range(thickness+1):
    print((c*thickness).______(thickness*2)+(c*thickness).______(thickness*6))

#Middle Belt
for i in range((thickness+1)//2):
    print((c*thickness*5).______(thickness*6))    

#Bottom Pillars
for i in range(thickness+1):
    print((c*thickness).______(thickness*2)+(c*thickness).______(thickness*6))    

#Bottom Cone
for i in range(thickness):
    print(((c*(thickness-i-1)).______(thickness)+c+(c*(thickness-i-1)).______(thickness)).______(thickness*6))

# %%
#Alphabet Rangoli	

def print_rangoli(size):
    # we begin by constructing the middle line to understand the required width needed
    abc = "abcdefghijklmnopqrstuvwxyz"
    count = 1
    string = abc[0]
    while count < size:
        string = string.center(len(string)+2,"-")
        string = string.center(len(string)+2,abc[count])
        count +=1  
    width = len(string)    
    #from here we will build each line up until the center line, and the reverse the process
    for x in range(1, size):
        line = abc[size-x]
        count=1
        while (size - x + count) < size:
            line = line.center(len(line)+2,"-")
            line = line.center(len(line)+2,abc[size - x + count])
            count +=1
        line= line.center(width,"-")        
        print(line)  
    # Here we print the middle string again
    print(string)
    # and we proceed to repeat the same algorithm in reverse
    for x in reversed(range(1, size)):
        line = abc[size-x]
        count=1
        while (size - x + count) < size:
            line = line.center(len(line)+2,"-")
            line = line.center(len(line)+2,abc[size - x + count])
            count +=1
        line= line.center(width,"-")        
        print(line)

# %%
# string formatting
def print_formatted(number):
    width = len(bin(number).lstrip("0b"))
    for x in range(1, number+1):
        print(str(x).rjust(width), oct(x).lstrip("0o").rjust(width), hex(x).lstrip("0x").rjust(width).upper(), bin(x).lstrip("0b").rjust(width))

# %%
#Capitalize!	


# Complete the solve function below.
def solve(s): 
    return " ".join([word.capitalize() for word in s.split(" ")])

# %%
#The Minion Game	

def minion_game(string):
    #counting for consonants
    cons = "bcdfghjklmnpqrstvwxyz".upper()
    vowels = "aeiou".upper()
    #kevin = {}
    #stuart ={}
    kevin_score = 0
    stuart_score = 0
    
    
    # iterating over the string, from taht index through every index till the end, if it starts with a vowel its added to kevin, otherwise to stuart. if we encounter the same substing twice we add that to a dictionary counter
    #for x in range(len(string)):
    #    for m in range(x,len(string)+1):
    #        if string[x] in cons:
    #            if string[x:m] in stuart:
    #                stuart[string[x:m]] += 1
    #            else:
    #                stuart[string[x:m]] = 1    
    #        else:
    #            if string[x:m] in kevin:
    #                kevin[string[x:m]] += 1 
    #            else:
    #                kevin[string[x:m]] = 1     
    #kevin[""]=0
    #stuart[""]=0        
            
    
    #This code was correctly solving most of them problem, but 4 testcases were not being completed in time. i resorted to chatGPT to help me optimize the code a so it runs faster, as follows
    
    for i in range(len(string)):
        if string[i] in cons:
            stuart_score += len(string) - i
        else:
            kevin_score += len(string) - i
    
    #for value in kevin.values():
    #    kevin_score += value
    #for value in stuart.values():
    #    stuart_score += value 
    
    if kevin_score > stuart_score:
        print("Kevin",kevin_score)
    elif kevin_score < stuart_score:
        print("Stuart",stuart_score)
    else:
        print("Draw")

# %%
#Merge the Tools!	
def merge_the_tools(string, k):
    # your code goes here
    substring =[]
    for x in range(0,len(string),k):
        substring.append(string[x:x+k])
    for m in range(len(substring)):
        cleaned = ""
        for char in substring[m]:
            if char not in cleaned:
                cleaned += char
        substring[m] = cleaned
                
    for x in substring:        
        print(x)

# %%
#Introduction to Sets	
def average(array):
    tot = sum(set(array))
    nb = len(set(array))
    
    return round(tot/nb,3)

# %%
#Symmetric Difference	

m = int(input())
M = set(map(int, input().split()))
n = int(input())
N = set(map(int, input().split()))


diff = list(map(int,N.symmetric_difference(M)))
diff.sort()

for i in diff:
    print(i)

# %%
#No Idea!	
n, m = map(int,input().split())
arr = list(map(int, input().split()))
A = set(map(int, input().split()))
B = set(map(int, input().split()))
happy =0
for i in arr:
    if i in A:
        happy +=1
    elif i in B:
        happy -= 1
print(happy)

# %%
#Set .add()	
# Enter your code here. Read input from STDIN. Print output to STDOUT
nbr = int(input())
unique = set()
for _ in range(nbr):
    unique.add(input())
print(len(set(unique)))

# %%
#Set .discard(), .remove() & .pop()	
n = int(input())
s = set(map(int, input().split()))
nbr = int(input())
for _ in range(nbr):
    command = input().split()
    if command[0] == "remove":
        s.remove(int(command[1]))
    elif command[0] == "discard":
        s.discard(int(command[1]))
    else:
        s.pop()
print(sum(s))

# %%
#Set .union() Operation	
# Enter your code here. Read input from STDIN. Print output to STDOUT
n = int(input())
english = set(input().split(" "))
m = int(input())
french = set(input().split(" "))

print(len(english.union(french)))

# %%
#Set .intersection() Operation	
# Enter your code here. Read input from STDIN. Print output to STDOUT
n = int(input())
english = set(input().split(" "))
m = int(input())
french = set(input().split(" "))
print(len(english.intersection(french)))

# %%
#Set .difference() Operation	
# Enter your code here. Read input from STDIN. Print output to STDOUT 
n = int(input())
english = set(input().split(" "))
m = int(input())
french = set(input().split(" "))
print(len(english.difference(french)))

# %%
#Set .symmetric_difference() Operation	
# Enter your code here. Read input from STDIN. Print output to STDOUT
n = int(input())
english = set(input().split(" "))
m = int(input())
french = set(input().split(" "))
print(len(english.symmetric_difference(french)))

# %%
#Set Mutations	
# Enter your code here. Read input from STDIN. Print output to STDOUT
a = int(input())
A = set(int(x) for x in input().split(" "))
nbr = int(input())
for i in range(nbr):
    operation = list(input().split(" "))
    N = set(int(x) for x in input().split(" "))
    if operation[0] == "intersection_update":
        A.intersection_update(N)
    elif operation[0] == "symmetric_difference_update":
        A.symmetric_difference_update(N)
    elif operation[0] == "difference_update":
        A.difference_update(N)
    elif operation[0] == "update":
        A.update(N)


print(sum(A))

# %%
#The Captain's Room	
# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import Counter
k = int(input())
rooms = Counter(input().split())
value = [int(i) for i in rooms if rooms[i]== 1]
print(value[0])

# %%
#Check Subset	
# Enter your code here. Read input from STDIN. Print output to STDOUT
t = int(input())
for i in range(t):
    a = int(input())
    A = (set(input().split()))
    b = int(input())
    B = set(input().split())
    if A.issubset(B):
        print(True)
    else:
        print(False)

# %%
#Check Strict Superset	
# Enter your code here. Read input from STDIN. Print output to STDOUT 
A= set(input().split())
n = int(input())
final = True
for i in range(n):
    test = set(input().split())
    if A.intersection(test) != test or test == A:
        final = False
        #print(test)
        break
    
print(final)

# %%
#collections.Counter()	
# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import Counter
shoe = int(input())
sizes = Counter([x for x in input().split()])
sold = dict.fromkeys(sizes, 0)

nbr = int(input())
profit=0

for x in range(nbr):
    pair = input().split()
    if pair[0] in sizes and sold[pair[0]] < sizes[pair[0]]:
        sold[pair[0]] +=1
        profit += int(pair[1])
        
       
print(profit)

# %%
#Calendar Module	
import calendar
m,d,y = input().split()
m=(int(m))
d=int(d)
y=int(y)
days = {0:"MONDAY", 1:"TUESDAY", 2:"WEDNESDAY", 3:"THURSDAY", 4:"FRIDAY", 5:"SATURDAY", 6:"SUNDAY" }
print(days[calendar.weekday(y,m,d)])

# %%
#Collections.OrderedDict()	
# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import OrderedDict
order = OrderedDict()
qty = int(input())
for x in range(qty):
    item = input().split()
    name = " ".join(item[:-1])
    if name not in order:
        order[name] = 0
    order[name] += int(item[-1])

for x in order:
    print(x, order[x])
    

# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import OrderedDict
order = OrderedDict()
qty = int(input())
for x in range(qty):
    item = input().split()
    name = " ".join(item[:-1])
    if name not in order:
        order[name] = 0
    order[name] += int(item[-1])

for x in order:
    print(x, order[x])

# %%
#Word Order	
# Enter your code here. Read input from STDIN. Print output to STDOut
from collections import Counter
nbr = int(input())
words =[]
for x in range(nbr):
    words.append(input())
count = Counter(words)  
print(len(count))
for value in count.values():
    print(value, end=" ")

# %%
#Collections.deque()	
# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import deque
d=deque()
n = int(input())
for _ in range(n):
    N=input().split()
    
    if N[0]=="append":
        d.append(N[1])
    if N[0]=="appendleft":
        d.appendleft(N[1])
    if N[0]=="pop":
        d.pop()
    if N[0]=="popleft":
        d.popleft()            
for x in d:
    print(x, end=" ")

# %%
#Company Logo	 I consulted the solution for help in sorting teh charachters in this exercise
#!/bin/python3
name = str(input())
import math
import os
import random
import re
import sys
from collections import Counter

char = []
for x in name:
    char.append(x)
count = Counter(char)  

sorted = sorted(count.keys(), key=lambda k: (-count[k], k))

for key in sorted[:3]:
    print(f"{key} {count[key]}")

# %%
#Piling Up!	
# Enter your code here. Read input from STDIN. Print output to STDOUT

t = int(input())
for _ in range(t):
    n = int(input())
    cube = []
    for x in input().split():
        cube.append(int(x))
    vert = []
    result = "Yes"
    last = 2**32
    #print(cube, vert)
    for x in range(len(cube)):
        left = cube[0]
        right = cube[-1]
        if left >= right and left <= last:
            last = left
            vert.append(last)
            cube.pop(0)
        elif right > left and right <= last:
            last = right
            vert.append(last)
            cube.pop(-1)  
        else:
            result = "No"
        #print(cube,vert,last)               
    print(result)

# %%
#Collections.namedtuple()	# Enter your code here. Read input from STDIN. Print output to STDOUT
n = int(input())
names = [x for x in input().split()]
scores =0
ind = names.index("MARKS")
#print(names, ind)
for x in range(n):
    std = [x for x in input().split()]
    scores += int(std[ind])
avg = scores / n
    
print(f"{avg:.2f}")

# Enter your code here. Read input from STDIN. Print output to STDOUT
n = int(input())
names = [x for x in input().split()]
scores =0
ind = names.index("MARKS")
#print(names, ind)
for x in range(n):
    std = [x for x in input().split()]
    scores += int(std[ind])
avg = scores / n
    
print(f"{avg:.2f}")

# %%
#Exceptions	
# Enter your code here. Read input from STDIN. Print output to STDOUT
a = int(input())
for x in range(a):
    b = [x for x in input().split()]
    
    try:
        print(int(b[0])//int(b[1]))
    except ZeroDivisionError as z:
        print("Error Code:",z)
    except ValueError as v:
        print("Error Code:",v )

# %%
#Time Delta	
#!/bin/python3

import math
import os
import random
import re
import sys
from datetime import datetime, timedelta

# Complete the time_delta function below.
def time_delta(t1, t2):
    t1 = datetime.strptime(t1,"%a %d %b %Y %H:%M:%S %z")
    t2 = datetime.strptime(t2,"%a %d %b %Y %H:%M:%S %z")
    delta = str(abs(int(timedelta.total_seconds(t1-t2))))
    
    return delta
    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()

        t2 = input()

        delta = time_delta(t1, t2)

        fptr.write(delta+"\n" )

    fptr.close()

# %%
#Zipped!	
# Enter your code here. Read input from STDIN. Print output to STDOUT
n = [int(x) for x in input().split()]
geo = []

for _ in range(n[1]):
    inp=list(map(float, input().split()))
    geo+=[inp]
m = list(zip(*geo))
for x in range(len(m)):
    print(sum(m[x])/n[1])

# %%
#Athlete Sort	
#!/bin/python3

import math
import os
import random
import re
import sys


if __name__ == '__main__':
    nm = input().split()

    n = int(nm[0])

    m = int(nm[1])

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    k = int(input())


arr = sorted(arr, key=lambda x: x[k])
for x in arr:
    for m in x:
        print(m, end = " ")
    print("")

# %%
#ginortS	
# Enter your code here. Read input from STDIN. Print output to STDOUT
s = input()
lower = sorted([x for x in s if x.islower()])
upper = sorted([x for x in s if x.isupper()])
even = sorted([x for x in s if x.isnumeric() and int(x) % 2 ==0])
odd = sorted([x for x in s if x.isnumeric() and int(x) % 2 ==1])
s = "".join([*lower, *upper, *odd, *even])
print(s)

# %%
#Detect Floating Point Number	
# Enter your code here. Read input from STDIN. Print output to STDOUT
t = int(input())
for _ in range(t):
    n = input()
    try:
        n = float(n)
        if n != 0.0:
            print(True)
        else:
            print(False)    
    except:
        print(False)

# %%
#Re.split()	
regex_pattern = r"[,.]"	# Do not delete 'r'.

import re
print("\n".join(re.split(regex_pattern, input())))

# %%
#Group(), Groups() & Groupdict()	
# Enter your code here. Read input from STDIN. Print output to STDOUT
s = input()
repeat = False
for x in range(len(s)-1):
    if s[x].isalnum() and s[x] == s[x+1]:
        print(s[x])
        repeat = True
        break
if repeat == False:
    print(-1)

# %%
#Map and Lambda Function	
cube = lambda x: x**3 

def fibonacci(n):
    fib = []
    a = 0
    while a<n:
        if a == 0:
            fib.append(a)
        elif a == 1:
            fib.append(1)
        else:
            fib.append(fib[a-2]+fib[a-1])
        a+=1
    return fib

# %%
#Birthday Cake Candles	
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'birthdayCakeCandles' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY candles as parameter.
#

def birthdayCakeCandles(candles):
    tall = max(candles)
    count=0
    for x in candles:
        if x == tall:
            count+=1
    return count        
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Number Line Jumps	
#!/bin/python3

import math
import os
import random
import re
import sys



#
# Complete the 'kangaroo' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. INTEGER x1
#  2. INTEGER v1
#  3. INTEGER x2
#  4. INTEGER v2
#

def kangaroo(x1, v1, x2, v2):
    if v1 != v2:
        coeff = (x2-x1) / (-v2+v1)
    else:
        return "NO"    
    if coeff > 0 and coeff.is_integer(): 
        return "YES"
    else:
        return "NO"    
        
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    x1 = int(first_multiple_input[0])

    v1 = int(first_multiple_input[1])

    x2 = int(first_multiple_input[2])

    v2 = int(first_multiple_input[3])

    result = kangaroo(x1, v1, x2, v2)

    fptr.write(result + '\n')

    fptr.close()

# %%
#Viral Advertising	
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'viralAdvertising' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER n as parameter.
#

def viralAdvertising(n):
    cum = 0
    count =0
    a,b = 5, int(5/2)
    for x in range(n):
        cum += b
        a = int(b*3) 
        b = int(a/2)
        print(a,b)
    return cum    
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = viralAdvertising(n)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Re.start() & Re.end()	
# Enter your code here. Read input from STDIN. Print output to STDOUT
s = input()
k = input()
instance = 0
for x in range(len(s)-len(k)+1):
    for m in range(len(k)):
        match = True
        if s[x+m] != k[m]:
            match = False
            break
    if match == True:
        print("({n}, {l})".format( n= x,l =x+len(k)-1 ))
        instance = 1
if instance == 0:
    print("(-1, -1)")

# %%
#Regex Substitution	
# Enter your code here. Read input from STDIN. Print output to STDOUT
import re
n = int(input())
indent = False
for _ in range(n):
    s=input()
    while " && " in s:
        s = re.sub(r" && ", " and ", s)
    while " || " in s:
        s = re.sub(r"\s\|\|\s", " or ", s)    
    print(s)

# %%
#Validating phone numbers	# Enter your code here. Read input from STDIN. Print output to STDOUT
n = int(input())
for x in range(n):
    s = input()
    if len(s) == 10 and s[0] in "789" and s.isnumeric():
        print("YES")
    else:
        print("NO")    

# Enter your code here. Read input from STDIN. Print output to STDOUT
n = int(input())
for x in range(n):
    s = input()
    if len(s) == 10 and s[0] in "789" and s.isnumeric():
        print("YES")
    else:
        print("NO")

# %%
#Arrays	


def arrays(arr):
    return (numpy.array(arr, float)[::-1])

# %%
#Shape and Reshape	
import numpy
m= [int(x) for x in input().split()]
n = numpy.array(m)

print(numpy.reshape(n,(3,3)))

# %%
#XML 1 - Find the Score	


def get_attr_number(node):
    count = 0
    for neighbor in node.iter():
        count += len(neighbor.attrib)
        
    return count

# %%
#XML2 - Find the Maximum Depth	


maxdepth = 0
def depth(elem, level):
    global maxdepth
    if level == maxdepth:
        maxdepth += 1 
    for nest in elem:
        depth(nest, level + 1)

# %%
#Insertion Sort - Part 2	

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort2' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#
def insertionSort2(n, arr):
    for i in range(1,n):
        m = i -1
        current = arr[i]
        while m>=0 and current < arr[m]:
            arr[m+1] = arr[m]
            m-=1
        arr[m + 1] = current
        for x in arr:
            print(x, end=" ")
        print("")    




#def insertionSort2(n, arr):
 #   pass# Write your code here

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort2(n, arr)

# %%
#Transpose and Flatten	
import numpy


x, y = input().split()
list1 = []
for _ in range(int(x)):
    l = list(map(int, input().split()))
    list1.append(l)
my_array = numpy.array(list1)
print(my_array.transpose())
print(my_array.flatten())

# %%
#Concatenate	
import numpy

n,m,p = map(int, input().split())
arr1 = list()
arr2 = list()
for x in range(n):
    arr1.append(list(map(int, input().split())))
for x in range(m):
    arr2.append(list(map(int, input().split())))
print(numpy.concatenate((numpy.array(arr1), numpy.array(arr2))))

# %%
#Eye and Identity	
import numpy
numpy.set_printoptions(legacy="1.13")
x,y = map(int, input().split())
matrix = numpy.eye(x,y, k=0)
print(matrix)

# %%
#Array Mathematics	import numpy

n, m = map(int, input().split())
a = numpy.array(list(map(int, input().split())))
for x in range(n-1):
    c=numpy.array(list(map(int, input().split())))
    a=numpy.vstack((a,c))
b = numpy.array(list(map(int, input().split())))
for x in range(n-1):
    
    c=numpy.array(list(map(int, input().split())))
    
    b=numpy.vstack((b,c))
if n == 1:    
    print("[%s]"%(a+b))
    print("[%s]"%(a -b))
    print("[%s]"%(a *b))
    print("[%s]"%(a //b))
    print("[%s]"%(a %b))
    print("[%s]"%(a **b))
else:
    print((a+b))
    print((a -b))
    print((a *b))
    print((a //b))
    print((a %b))
    print((a **b))



import numpy

n, m = map(int, input().split())
a = numpy.array(list(map(int, input().split())))
for x in range(n-1):
    c=numpy.array(list(map(int, input().split())))
    a=numpy.vstack((a,c))
b = numpy.array(list(map(int, input().split())))
for x in range(n-1):
    
    c=numpy.array(list(map(int, input().split())))
    
    b=numpy.vstack((b,c))
if n == 1:    
    print("[%s]"%(a+b))
    print("[%s]"%(a -b))
    print("[%s]"%(a *b))
    print("[%s]"%(a //b))
    print("[%s]"%(a %b))
    print("[%s]"%(a **b))
else:
    print((a+b))
    print((a -b))
    print((a *b))
    print((a //b))
    print((a %b))
    print((a **b))

# %%
#Floor, Ceil and Rint	
import numpy
import math
numpy.set_printoptions(legacy="1.13")
arr = numpy.array(list(map(float,input().split())))
print(numpy.floor(arr))
print(numpy.ceil(arr))
print(numpy.rint(arr))

# %%
#Sum and Prod	
import numpy

n,m = map(int, input().split())
l=list()
for _ in range(m):
    l.append(list(map(int, input().split())))    
arr = numpy.array(l)
add =numpy.sum(arr, axis = 0)
#print(add)
print(numpy.prod(add, axis = 0))

# %%
#Min and Max	
import numpy

n,m = map(int, input().split())
l=list()
for _ in range(n):
    l.append(list(map(int, input().split())))
arr = numpy.array(l) 
print(numpy.max(numpy.min(arr, axis = 1) ))

# %%
#Mean, Var, and Std	
import numpy
#numpy.set_printoptions(legacy="1.13")

n,m = map(int, input().split())
l=list()
for _ in range(n):
    l.append(list(map(int, input().split())))
arr = numpy.array(l)
print(numpy.mean(arr, axis = 1))
print(numpy.var(arr, axis = 0))
print(round(numpy.std(arr, axis = None),11))

# %%
#Dot and Cross	
import numpy
n = int(input())
l=list()
m=list()
for _ in range(n):
    l.append(list(map(int, input().split())))
for _ in range(n):
    m.append(list(map(int, input().split())))    
arr1 = numpy.array(l)
arr2 = numpy.array(m)
#print(arr1, arr2)
print(numpy.matmul(arr1,arr2))

# %%
#Inner and Outer	
import numpy

arr1 = numpy.array(list(map(int, input().split())))
arr2 = numpy.array(list(map(int, input().split())))

print(numpy.inner(arr1,arr2))
print(numpy.outer(arr1,arr2))

# %%
#Polynomials	
import numpy
arr = numpy.array(list(map(float, input().split())))
x = int(input())

print(numpy.polyval(arr, x))

# %%
#Linear Algebra	
import numpy

n = int(input())
l=list()
for _ in range(n):
    l.append(list(map(float, input().split())))
arr = numpy.array(l)
print(round(numpy.linalg.det(arr),2))

# %%
#Lists	
if __name__ == '__main__':
    N = int(input())
a = list()
for x in range(N):
    fnc = input().split()
    
    if fnc[0] =="insert":
        a.insert(int(fnc[1]),int(fnc[2]))
    elif fnc[0] == "print":
        print(a)    
    elif fnc[0] == "reverse":    
        a.reverse()
    elif fnc[0] == "remove": 
        a.remove(int(fnc[1]))   
    elif fnc[0] == "append":
        a.append(int(fnc[1]))    
    elif fnc[0] == "pop":    
        a.pop()
    elif fnc[0] == "sort":  
        a.sort()
